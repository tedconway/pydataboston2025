# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tedconway/pydataboston2025/blob/main/demo4pydata2025.ipynb)<br><b>Fun With Python and Em🙂ji: What Might Adding Pictures to Text Programming Languages Look Like?</b>

# %%
#emoji2text_off                         # Turn off emoji2text mode temporarily using comment at start of cell while defining dictionary
# Create global emoji-to-text Python dictionary, set global indicator that translation is active (only needs to run once)
global emoji2text_dict, emoji2txt
emoji2text_dict = {
'🤔':'if', '❎':'else', '🖨️':'print',
'🐼':'pandas', '🦆':'duckdb', '📈':'plotly', '𝄜':'excel',
'🔤':'str', '💾':'data', '📅':'date', '🕙':'time', '🔄':'while',
'🛢':'create table', '🗑️':'drop table', '🛒':'select', '⬅️':'from',
'🔗':'join', '↕️':'order by', '⬇️':'asc', '⬇️':'desc', '∑':'group by',
'🚗':'cars'}
globals()['emoji2txt']=True             # With dictionary defined, turn emoji2text mode on via global variable emoji2txt

# %%
# Define/activate IPyton Input Transformer to translate emojis in submitted cells into text for Python (only needs to run once)
import regex, json, pandas as pd

# Parse submitted Python code for emojis, other characters
def grapheme_positions(text):
    matches = regex.finditer(r'\X', text)
    return [{'grapheme': m.group()} for m in matches]

# Process submitted Python code, replacing emojis with assoicated code from global dictionary
def emoji2text(lines):
    global emoji2txt
    global emoji2text_dict
    emoji2text_off=False
    if "".join(lines[0][:15])=="#emoji2text_off": emoji2text_off=True
    if emoji2text_off==True or 'emoji2txt' not in globals():
        return lines
    if emoji2txt==False:
        return lines
    df = pd.DataFrame.from_dict(grapheme_positions("".join(lines)), orient='columns')
    df['replstr'] = df['grapheme'].map(emoji2text_dict)
    #df['replstr'].fillna(df['grapheme'], inplace=True)
    df['replstr'] = df['replstr'].fillna(df['grapheme'])
    return "".join(df["replstr"].tolist()).splitlines(keepends=True)

# Add emoji2text input transformer after deleting any existing instances
ip = get_ipython();
for i in range(len(ip.input_transformers_cleanup)-1,-1,-1):
  if type(ip.input_transformers_cleanup[i]).__name__=='function':
    if ip.input_transformers_cleanup[i].__name__=='emoji2text':
      del ip.input_transformers_cleanup[i]
ip = get_ipython()
ip.input_transformers_cleanup.append(emoji2text)

# %%
# Emoji-free version of test code (emoji version of test code in next cell)
import pandas, duckdb, plotly.express as plotly           # Import packages
from datetime import datetime

print(datetime.now().strftime("%Y-%m-%d"))                # Python statements
if datetime.now().weekday() in (5, 6):
    print ("It's the weekend!")
else:
    print("\nIt's a work day!")
                                                          # Get test data (cars.csv)
df_cars=pandas.read_csv('https://raw.githubusercontent.com/tedconway/pydataboston2025/refs/heads/main/cars.csv')
                                                          # DuckDB SQL
cars_summary=duckdb.sql('''
select type, avg(MPG_City) as Avg_MPG_City, Avg(MSRP) as avg_MSRP
from df_cars
group by 1 order by 2 desc, 1
'''
).df()
print("\n",cars_summary)
                                                          # Plotly bar chart
plotly.bar(cars_summary, x='Type', y='Avg_MPG_City').show()
# Out:
# 2025-12-20
# It's the weekend!
#
#       Type  Avg_MPG_City      avg_MSRP
# 0  Hybrid     55.000000  19920.000000
# 1   Wagon     21.100000  28840.533333
# 2   Sedan     21.083969  29773.618321
# 3  Sports     18.408163  53387.061224
# 4   Truck     16.500000  24941.375000
# 5     SUV     16.100000  34790.250000

# %%
# Emoji+text version of test code
import 🐼, 🦆, 📈.express as 📈                         # Import packages
from 📅🕙 import 📅🕙

🖨️(📅🕙.now().strftime("%Y-%m-%d"))                     # Python statements
🤔 📅🕙.now().weekday() in (5, 6):
    🖨️("It's the weekend!")
❎:
    🖨️("\nIt's a work day!")
                                                         # Test data (cars.csv)
df_🚗=🐼.read_csv('https://raw.githubusercontent.com/tedconway/pydataboston2025/refs/heads/main/🚗.csv')
                                                         # DuckDB SQL
🚗_summary=🦆.sql('''
🛒 type, avg(MPG_City) as Avg_MPG_City, Avg(MSRP) as Avg_MSRP
from df_🚗 ∑ 1 ↕️ 2 ⬇️, 1
'''
).df()
🖨️("\n",🚗_summary)
                                                         # Plotly bar chart
📈.bar(🚗_summary, x='Type', y='Avg_MPG_City').show()
# Out:
# 2025-12-20
# It's the weekend!
#
#       Type  Avg_MPG_City      Avg_MSRP
# 0  Hybrid     55.000000  19920.000000
# 1   Wagon     21.100000  28840.533333
# 2   Sedan     21.083969  29773.618321
# 3  Sports     18.408163  53387.061224
# 4   Truck     16.500000  24941.375000
# 5     SUV     16.100000  34790.250000

# %%
#emoji2text_off                                           # Add entry to emoji2text_dict
emoji2text_dict["🐶"]="DOG"
emoji2text_dict
# Out:
# {'🤔': 'if',
#  '❎': 'else',
#  '🖨️': 'print',
#  '🐼': 'pandas',
#  '🦆': 'duckdb',
#  '📈': 'plotly',
#  '𝄜': 'excel',
#  '🔤': 'str',
#  '💾': 'data',
#  '📅': 'date',
#  '🕙': 'time',
#  '🔄': 'while',
#  '🛢': 'create table',
#  '🗑️': 'drop table',
#  '🛒': 'select',
#  '⬅️': 'from',
#  '🔗': 'join',
#  '↕️': 'order by',
#  '⬇️': 'desc',
#  '∑': 'group by',
#  '🚗': 'cars',
#  '🐶': 'DOG'}

# %%
print("🐶")                                              # Show that it works!
# Out:
# DOG

# %%
#emoji2text_off                                          # Delete entry from emoji2text_dict
emoji2text_dict.pop("🐶")
emoji2text_dict
# Out:
# {'🤔': 'if',
#  '❎': 'else',
#  '🖨️': 'print',
#  '🐼': 'pandas',
#  '🦆': 'duckdb',
#  '📈': 'plotly',
#  '𝄜': 'excel',
#  '🔤': 'str',
#  '💾': 'data',
#  '📅': 'date',
#  '🕙': 'time',
#  '🔄': 'while',
#  '🛢': 'create table',
#  '🗑️': 'drop table',
#  '🛒': 'select',
#  '⬅️': 'from',
#  '🔗': 'join',
#  '↕️': 'order by',
#  '⬇️': 'desc',
#  '∑': 'group by',
#  '🚗': 'cars'}
